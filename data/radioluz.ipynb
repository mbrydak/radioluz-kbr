# %%
# !pip install pandas pandas-ods-reader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 3.1 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 2.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 2.8 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 3.2 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for ezodf: filename=ezodf-0.3.2-py2.py3-none-any.whl size=49002 sha256=e28d196a9400bdf13b5eb3c3a860415aa097a9514dd16687f0c87638c510e79a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/42/d4/7a/22ed49343f90c615172ca912882fa3bc915dbbe98669ecad48
# Successfully built ezodf
# ...

# %%
import pandas as pd
from pandas_ods_reader import read_ods
import os

# %%
ods_files = []
excel_files = []
for filename in os.scandir("data_raw"):
    if filename.is_file():
        if filename.name.__contains__('.xls') or filename.name.__contains__('.xlsx'):
            excel_files.append(filename.path)
        elif filename.name.__contains__('.ods'):
            ods_files.append(filename.path)

# %%
ods_files
# Out:
# ['data_raw/Presspack_miasta_fala-styczen-2019-czerwiec-2019.ods',
#  'data_raw/Presspack_miasta_fala-listopad-2018-kwiecien-2019.ods',
#  'data_raw/Presspack_miasta_fala-czerwiec-listopad-2018.ods',
#  'data_raw/Presspack_miasta_fala-styczen-czerwiec-2018.ods',
#  'data_raw/Presspack_miasta_fala-listopad-2017-kwiecien-2018.ods',
#  'data_raw/Presspack_miasta_fala-wrzesien-2017-luty-2018.ods',
#  'data_raw/Presspack_miasta_fala-sierpien2017-styczen-2018.ods',
#  'data_raw/Presspack_miasta_fala-czerwiec-listopad_2017-kmb.ods',
#  'data_raw/Presspack_miasta_marzec-sierpien_2017.ods',
#  'data_raw/Presspack_miasta_luty-lipiec2017.ods',
#  'data_raw/Presspack_miasta_styczen_2016_czerwiec_2017-19.07.ods',
#  'data_raw/listopad-2016-kwiecien-2017.ods',
#  'data_raw/Presspack_wrzesien_2016_miasta-1.ods',
#  'data_raw/LUTY-2016-LIPIEC-2016.ods']

# %%
excel_files
# Out:
# ['data_raw/Presspack-Słuchalność-w-miastach-kwiecień_wrzesień_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-marzec_sierpień_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-luty_lipiec_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-styczeń_czerwiec_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-grudzień_2021_maj_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-listopad-_2021_kwiecień_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-październik_2021_marzec_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-wrzesień_2021_luty_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-sierpień_2021_styczeń_2022.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-lipiec-grudzień-2021.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-czerwiec-listopad-2021.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-maj-pażdziernik-2021.xlsx',
#  'data_raw/Presspack-Słuchalność-w-miastach-kwiecień-wrzesień-2021.xlsx',
# ...

# %%
for file in ods_files:
    df_ods = read_ods(file)
    print(file)
    print(df_ods.head(15))
# Out:
# data_raw/Presspack_miasta_fala-styczen-2019-czerwiec-2019.ods
#                      SoftReport Explorer - 10.07.2019  \
# 0                                                None
# 1                          Badanie: Radio Track - KBR
# 2                                       Kantar Polska
# 3                                                None
# 4                                                None
# 5                                                None
# 6   PRZYPOMINAMY UŻYTKOWNIKOM, ŻE ZGODNIE Z ZALECE...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                          Radio ZET
# 11                                       Radio RMF FM
# 12                                       Radio TOK FM
# 13                 Trójka - Program 3 Polskiego Radia
# 14                                Radio ESKA Warszawa
#
# ...

# %%
df_ods.head(15)
# Out:
#                      SoftReport Explorer - 10.07.2019  \
# 0                                                None
# 1                          Badanie: Radio Track - KBR
# 2                                       Kantar Polska
# 3                                                None
# 4                                                None
# 5                                                None
# 6   PRZYPOMINAMY UŻYTKOWNIKOM, ŻE ZGODNIE Z ZALECE...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                          Radio ZET
# 11                                       Radio RMF FM
# 12                                       Radio TOK FM
# 13                 Trójka - Program 3 Polskiego Radia
# 14                                Radio ESKA Warszawa
#
#                       unnamed.1                     unnamed.2  \
# ...

# %%
df_ods.iloc[9].iloc[0] = 'radio_station'

# %%
df_ods = df_ods[9:37]
df_ods.reset_index(drop=True, inplace = True)

# %%
df_ods.head(5)
# Out:
#      SoftReport Explorer - 10.07.2019                    unnamed.1  \
# 0                       radio_station  lipiec 2017 : grudzień 2017
# 1                           Radio ZET                     0.104243
# 2                        Radio RMF FM                     0.105399
# 3                        Radio TOK FM                     0.103492
# 4  Trójka - Program 3 Polskiego Radia                     0.090118
#
#                       unnamed.2                    unnamed.3  \
# 0  styczeń 2018 : czerwiec 2018  lipiec 2018 : grudzień 2018
# 1                      0.124699                     0.096465
# 2                      0.090324                     0.093352
# 3                      0.105215                     0.084834
# 4                      0.082152                     0.080254
#
#                       unnamed.4
# 0  styczeń 2019 : czerwiec 2019
# 1                      0.122389
# 2                      0.098926
# 3                      0.091361
# ...

# %%
len(df_ods.iloc[0])
# Out:
# 5

# %%
new_columns_arr = []
for counter in range(len(df_ods.iloc[0])):
    new_columns_arr.append(df_ods.iloc[0][counter])
    print(new_columns_arr)
# Out:
# ['radio_station']
# ['radio_station', 'lipiec 2017 : grudzień 2017']
# ['radio_station', 'lipiec 2017 : grudzień 2017', 'styczeń 2018 : czerwiec 2018']
# ['radio_station', 'lipiec 2017 : grudzień 2017', 'styczeń 2018 : czerwiec 2018', 'lipiec 2018 : grudzień 2018']
# ['radio_station', 'lipiec 2017 : grudzień 2017', 'styczeń 2018 : czerwiec 2018', 'lipiec 2018 : grudzień 2018', 'styczeń 2019 : czerwiec 2019']

# %%
df_ods.head(5)
# Out:
#      SoftReport Explorer - 10.07.2019                    unnamed.1  \
# 0                       radio_station  lipiec 2017 : grudzień 2017
# 1                           Radio ZET                     0.104243
# 2                        Radio RMF FM                     0.105399
# 3                        Radio TOK FM                     0.103492
# 4  Trójka - Program 3 Polskiego Radia                     0.090118
#
#                       unnamed.2                    unnamed.3  \
# 0  styczeń 2018 : czerwiec 2018  lipiec 2018 : grudzień 2018
# 1                      0.124699                     0.096465
# 2                      0.090324                     0.093352
# 3                      0.105215                     0.084834
# 4                      0.082152                     0.080254
#
#                       unnamed.4
# 0  styczeń 2019 : czerwiec 2019
# 1                      0.122389
# 2                      0.098926
# 3                      0.091361
# ...
